# %% [markdown]
# # Question 3

# %% [markdown]
# # Part a

# %% [markdown]
# The function mt2pcm is used to convert the (unquantized) samples of a message signal mt to a PCM bit string dn with bits bit quantization per sample. The function pcm2mt is used to convert the bit string dn back to “analog” samples. The message signal used is a sine signal of frequency 100

# %% [markdown]
# First this is done for 3 bit quantisation with sampling rate varying from 4000 to 8000

# %%
run sinewave
# Out:
# Enter sampling rate Fs in Hz:  4000

# %%
run sinewave
# Out:
# Enter sampling rate Fs in Hz:  6000

# %%
run sinewave
# Out:
# Enter sampling rate Fs in Hz:  8000

# %% [markdown]
# Second this is done for 8 bit quantisation with the sampling rate varying from 4000 to 8000

# %%
run sinewave
# Out:
# Enter sampling rate Fs in Hz:  4000

# %%
run sinewave
# Out:
# Enter sampling rate Fs in Hz:  6000

# %%
run sinewave
# Out:
# Enter sampling rate Fs in Hz:  8000

# %% [markdown]
# ## Part b

# %% [markdown]
# Using the PCM test signals in pcm_test01.wav and pcm_test02.wav to test your PCM receiver.

# %% [markdown]
# The ﬁrst test signal is a 3-bit (sign-magnitude, MSB ﬁrst) PCM signal with bit rate Fb = 24000

# %%
run TestingPCM

# %% [markdown]
# second test signal is a 8-bit (sign-magnitude, MSB ﬁrst) PCM signal.

# %%
run TestingPCM

# %% [markdown]
# For pcm_sig01 and pcm_sig02 I was only able to hear a short burst of noise.
