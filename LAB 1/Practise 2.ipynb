# %%
import sine100.py
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Swarupa De\Anaconda3\envs\comm lab\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-136088645f9e>", line 1, in <module>
#     import sine100.py
#
#   File "C:\Users\Swarupa De\Documents\Python_Scripts\sine100.py", line 3
#     Fs = literal_eval(input(’Enter sampling rate Fs in Hz: ’))
#                                  ^
# SyntaxError: invalid character in identifier

# %%
import sine100.py
# Out:
# Enter sampling rate Fs in Hz: 200
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-136088645f9e> in <module>
# ----> 1 import sine100.py
#
# ModuleNotFoundError: No module named 'sine100.py'; 'sine100' is not a package

# %%
run sine100.py
# Out:
# Enter sampling rate Fs in Hz: 200

# %%
run sine100.py
# Out:
# Enter sampling rate Fs in Hz: 200

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 200

# %%
run sine100

# %%
run sine100

# %%
run sine100
# Out:
#   File "C:\Users\Swarupa De\Documents\Python_Scripts\sine100.py", line 6
#     f0 = 100
#      ^
# SyntaxError: invalid syntax

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Documents\Python_Scripts\sine100.py in <module>
#       7 tlen = 5e-2
#       8 tt = arange(0,round(tlen*Fs))/float(Fs)
# ----> 9 st = sin(2*pi*f0*tt)
#      10 plot(tt[0:24], st[0:24])
#      11 grid()
#
# NameError: name 'f0' is not defined

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 200
