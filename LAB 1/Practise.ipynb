# %% [raw]
# run sine100

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 200

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 200

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 600

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 700

# %%
run sine800
# Out:
# ERROR:root:File `'sine800.py'` not found.

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 800

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 900

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 1000

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 1100

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 1200

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 1600

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 3200

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 3200

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 200

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 400

# %%
run sine100
# Out:
# Enter sampling rate Fs in Hz: 800

# %%
import wavread

# %%
import wavfun

# %%
run wavfun

# %%
wavread(sig01.wav)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-38102e0c2108> in <module>
# ----> 1 wavread(sig01.wav)
#
# NameError: name 'sig01' is not defined

# %%
wavread("sig01.wav")
# Out:
# (3000, array([ 0.        ,  0.79500717, -0.3647267 ,  0.01113926, -0.54646444,
#          0.47917113,  0.5637074 , -0.81981874,  0.10702841, -0.08874783,
#          0.5497604 ,  0.0334788 , -0.9284646 ,  0.5710318 ,  0.11236915,
#          0.18936735, -0.33402508, -0.56663716,  0.9693899 , -0.16315195,
#         -0.21744438, -0.23282571, -0.05182043,  0.9261452 , -0.6811121 ,
#         -0.24344616,  0.19821772,  0.15717033,  0.47904906, -0.974395  ,
#          0.17685476,  0.5073092 , -0.1060213 ,  0.04361095, -0.78475296,
#          0.6847438 ,  0.35734123, -0.558092  ,  0.02026429, -0.30689412,
#          0.83635974, -0.15460677, -0.7345195 ,  0.4155095 , -0.00421155,
#          0.5223548 , -0.5887936 , -0.4293344 ,  0.835963  , -0.17023225,
#          0.07101657, -0.5784478 ,  0.10971404,  0.860622  , -0.6508072 ,
#         -0.0626545 , -0.17633595,  0.41511276,  0.43952757, -0.99002045],
#        dtype=float32))

# %%
run wavread

# %%
run wavread
# Out:
# 3000
