# %% [markdown]
# # Experiment Q2 (a)

# %% [markdown]
# We first convert the DT sequence an in sig_an to the CT signal as(t) and then passing the result through a shaping ﬁlter with h(t) = p(t)

# %% [markdown]
# We first generate a discrete time sequence for "Test" and convert to a continous time signal and pass the result through a rectangular p(t)

# %%
run Q2A

# %% [markdown]
# The following figure is after passing the same c(t) signal through a Triangular p(t)

# %%
run Q2A

# %% [markdown]
# The following figure is after passing the same c(t) signal through a windowed and Truncated sinc p(t)

# %%
run Q2A

# %% [markdown]
# # Experiment Q2(b)

# %% [markdown]
# Generating a random polar binary message sequence of length approximately 0.5 sec using the Python commands.
#
# Then using the pam10 function to generate PAM signals s(t) from an with rectangular p(t)

# %%
run Q2B

# %% [markdown]
# In the next case we use a triangular p(t)

# %%
run Q2B

# %% [markdown]
# For the following case we use a sinc p(t)

# %%
run Q2B
