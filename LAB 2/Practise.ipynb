# %%
run Q1A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Documents\Python_Scripts\LAB 2\Q1A.py in <module>
#       9 xt = np.sin(2*np.pi*fa*tt)-0.01*np.cos(2*np.pi*fb*tt) # Linear combination of sinusoids
#      10 sig_xt = comsig.sigWave(xt, Fs, 0) # Waveform from class sigWave
# ---> 11 showfun.showft(sig_xt,[-200,200,1e-3]) # Display X(f), using ff_lim
#
# ~\Documents\Python_Scripts\LAB 2\showfun.py in showft(sig_xt, ff_lim)
#      53     af12.set_ylabel("arg[X(f)] [deg]")
#      54     af12.set_xlabel("f [Hz]")
# ---> 55
#      56
#
# NameError: name 'show' is not defined

# %%
run Q1A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Documents\Python_Scripts\LAB 2\Q1A.py in <module>
#       9 xt = np.sin(2*np.pi*fa*tt)-0.01*np.cos(2*np.pi*fb*tt) # Linear combination of sinusoids
#      10 sig_xt = comsig.sigWave(xt, Fs, 0) # Waveform from class sigWave
# ---> 11 showfun.showft(sig_xt,[-200,200,1e-3]) # Display X(f), using ff_lim
#
# ~\Documents\Python_Scripts\LAB 2\showfun.py in showft(sig_xt, ff_lim)
#      53     af12.set_ylabel("arg[X(f)] [deg]")
#      54     af12.set_xlabel("f [Hz]")
# ---> 55
#
# NameError: name 'show' is not defined

# %%
import numpy as np 
import comsig 
Fs = 16000 
f0 = 100 
tlen = 0.1 
tt = np.arange(np.round(tlen*Fs))/float(Fs) # Instantiate waveform sig0 with sampling rate Fs and t0=-0.05 
sig0 = comsig.sigWave(1.5*np.sin(2*np.pi*f0*tt),Fs,-0.05)
print(sig0.__len__)
# Out:
# <bound method sigWave.__len__ of <comsig.sigWave object at 0x000001A1A2FBF9E8>>

# %%
run Q1A

# %%
run Q1A

# %%
run Q1A

# %%
import numpy as np 
import comsig 
import showfun 
import importlib
importlib.reload(showfun)
import ftpam01 as ft

showfun.showft(ft.sdit,[-2000,2000,-40])

# %%
run Q2C

# %%
run Q3A
# Out:
# The bit rate is below
# 253.44827586206895

# %%
run Q3A
# Out:
# The bit rate is below
# 253.44827586206895

# %%
run Q3A
# Out:
# The bit rate is below
# 253.44827586206895
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Documents\Python_Scripts\LAB 2\Q3A.py in <module>
#      67
#      68 print("")
# ---> 69 print('The content of the wav file is "%s"' %af.bin2asc(dnhat))
#      70 print("")
#
# ~\Documents\Python_Scripts\LAB 2\ascfun.py in bin2asc(dn, bits, flg)
#      32 	"""
#      33         N = int(dn.size/bits)
# ---> 34         C = reshape(dn,(N,bits)).astype(int)
#      35
#      36         if bits > 0:
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     277            [5, 6]])
#     278     """
# --> 279     return _wrapfunc(a, 'reshape', newshape, order=order)
#     280
#     281
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      49 def _wrapfunc(obj, method, *args, **kwds):
# ...

# %%
from pylab import *
import ascfun as af
import wavfun as wf
fs, rt  = wf.wavread("pamsig201.wav")
fb= 251
tb = 1/float(fb)
bits = 8
n = int(floor(len(rt)/float(fs)/tb))  #number of recieved bits
rt= list(rt)

######### getting sample of rt signal #######
dnhat=[]
for i in range(n):                      # getting sample of rt signal
	dn_sample = rt[i*round(fs*tb):int(((i+1))*round(fs*tb))]
	avg = sum(dn_sample) / round(fs*tb) # averaging out the one bit window and the comapring
	if avg > 0.5:                       # Quantisation of the bits
		dnhat = dnhat + [1]
	else:
		dnhat = dnhat + [0]
#####################################################
dnhat = array(dnhat,int8)	 # converting list into binary array

print("")
print('The content of the wav file is "%s"' %af.bin2asc(dnhat))
print("")
# Out:
# The content of the wav file is "low`ng`n`@@f@L@"

# %%
run Q3A
# Out:
# The bit rate is below
# 201.36986301369862
