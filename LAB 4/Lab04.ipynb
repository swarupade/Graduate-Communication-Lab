# %% [markdown]
# # Experiment 1 (a)

# %% [markdown]
# ## Visualisation of the sampling theorem. waveform used is a cosine waveform with frequency of 2700Hz

# %%
from IPython.display import Image
Image(filename='capture.png')

# %%
from IPython.display import Image
Image(filename='capture.png')

# %% [markdown]
# The reconstructed does not have the frequency of 2700 Hz. This is because this value is larger than (Fs/2 = 2000) Hz. hence it violates the Nyquists criterion and the waveform is not reconstructed correctly.

# %% [markdown]
# # Expt 1(b)

# %% [markdown]
# ## Using a 1000 Hz squarewave with the same flowgraph as in (a).
#
# #### Changing the Frequency from 1000 Hz to 1200 Hz

# %%
from IPython.display import Image
Image(filename='capture.png')

# %% [markdown]
# We see that the reconstructed waveform is no longer square. This is because we are using a sinc pulse to interpolate the waveform.

# %%
from IPython.display import Image
Image(filename='capture.png')

# %% [markdown]
# The waveform is now completely haywire since the frequency is now violates the Nyquist Frequency and hence the wave cannot be reconstructed correctly.

# %% [markdown]
# # Expt 1(c)

# %% [markdown]
# ## Using a bandpass filter to reconstruct a CT waveform

# %%
from IPython.display import Image
Image(filename='capture.png')

# %%
from IPython.display import Image
Image(filename='capture.png')

# %% [markdown]
# verifying that the input and out waveforms are the same

# %%
from IPython.display import Image
Image(filename='capture.png')

# %% [markdown]
# # Expt 1(d)

# %% [markdown]
# ## generating Rcf pulse and the manchester pulse

# %%
run Q1D

# %%
run Q1D

# %% [markdown]
# # Expt 1 (e)
# ## Generating the Fourier Transform for the pulses generated above

# %% [markdown]
# For the manchester pulse

# %%
run Q1E

# %% [markdown]
# For the RCF pulse

# %%
run Q1E

# %% [markdown]
# # Expt 2(a)

# %% [markdown]
# ## Generating an eye diagram with random data

# %%
run Q2A

# %% [markdown]
# # Expt 2(b)

# %% [markdown]
# ## analysis of pamsig401

# %%
run Q2B

# %% [markdown]
# By manually observing the signal in the time domain we observe that the baud rate is approximately 1bit per 0.002sec. The signal also appears to be bipolar binary.  We obtain multiple eye diagrams and FFT by changing the FB to different approximations and choosing the best one.

# %%
run Q2B

# %%
run Q2B

# %%
run Q2B

# %%
run Q2B

# %% [markdown]
# Thus we can conclude that for FB=340 we get the best eye diagram. We can also conclude that the signal only has two levels. It also appears as if the signal suffers from some time jitters

# %%
run Q2B

# %% [markdown]
# After looking at the FFT it seems that the interpolation signal maybe a rcf signal

# %% [markdown]
# # Analysis of Pamsig402

# %%
run Q2B

# %% [markdown]
# From observing the signal in the time axis we observe that the signal has a baud rate of approximately 9 bits per 0.05 sec. The signal also uses a minimum of 5 levels. We obtain multiple eye diagrams and FFT by changing the FB to different approximations and choosing the best one.

# %%
run Q2B

# %%
run Q2B

# %%
run Q2B

# %%
run Q2B

# %% [markdown]
# run Q2B

# %% [markdown]
# From the eye diagrams we can tell that the signal has some time jitter and the FB is probably equal to 210 as the eye diagram is the best for this bit rate. From the FFT we can conclude that the interpolating signal was Rcf

# %% [markdown]
# # Expt 2(c)

# %% [markdown]
# ### for Fl = 0.25* Fl

# %%
run Q2B

# %% [markdown]
# ## For Fl = 0.5 *Fl

# %%
run Q2B

# %%
run Q2B

# %% [markdown]
# For a high Fl = 10*FB

# %%
run Q2B

# %% [markdown]
# For reasonable detection Fl =0.5 * FB will survive

# %% [markdown]
# To determine the N and Fl of the filter used in the given picture, We try different combinations of N and Fl

# %% [markdown]
# for a high N

# %%
run Q2B

# %% [markdown]
# For Low L

# %%
run Q2B

# %% [markdown]
# For high Fl

# %%
run Q2B

# %% [markdown]
# As we can see from these extra plots, low N's create the desired "flatness" on the top and bottom of the traces of the eye diagram and lower fL's create the slow, curved transitions (rather than steep, vertical transitions with high fL's)
#
# Also from the diagram the curves look like ethe charging and discharging of capacitors in order 1 RC filter circuits. Thus possible values can be N= 1 and Fl= 0.5*Fb

# %% [markdown]
# # Expt 3(a)

# %% [markdown]
# ## Generating a PAM signal using a Class 1 PR1 signal

# %%
run Q3A

# %% [markdown]
# # Expt 3(b)

# %% [markdown]
# ## Comparing the FT of a PR1 pulse(i) and the FT of a sinc pulse(ii)

# %%
run Q1E

# %%
run Q1E

# %%
run Q1E

# %% [markdown]
# # Expt 3(c)

# %%
run Q3C
# Out:
# A leader knows what the best thing to do is;
# a manager only knows how to do it best

# %% [markdown]
# # Expt 3(d)
